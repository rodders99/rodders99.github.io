# %%
img_dict={"Automotive":"car.png",
"Breathing Obstruction":"breathing.png",
"Chemical":"laboratory.png",
"Chemicals":"laboratory.png",
"Childcare Equipment":"childcare.png",
"Clothing & Fashion":"fashion.png",
"Cosmetics":"skincare.png",
"Electric Shock":"flash.png",
"Electrical Appliances":"home-appliance.png",
"Environment":"environmental.png",
"Fire":"fire.png",
"Injuries":"patient.png",
"Jewellery":"diamond-ring.png",
"Microbiological":"microbiology.png",
"Toys":"toys.png",
          "other": "other.png",
          

         }

# %%
img_dict
# Out:
# {'Automotive': 'car.png',
#  'Breathing Obstruction': 'breathing.png',
#  'Chemical': 'laboratory.png',
#  'Chemicals': 'laboratory.png',
#  'Childcare Equipment': 'childcare.png',
#  'Clothing & Fashion': 'fashion.png',
#  'Cosmetics': 'skincare.png',
#  'Electric Shock': 'flash.png',
#  'Electrical Appliances': 'home-appliance.png',
#  'Environment': 'environmental.png',
#  'Fire': 'fire.png',
#  'Injuries': 'patient.png',
#  'Jewellery': 'diamond-ring.png',
#  'Microbiological': 'microbiologypng',
#  'Toys': 'toys.png'}

# %%
df = pd.DataFrame({'column': {0: 'Chemical', 1: 'Injuries', 2: 'Breathing Obstruction', 3: 'Toys', 4: 'Electrical Appliances', 5: 'other', 6: 'Chemical', 7: 'Injuries', 8: 'Fire', 9: 'Cosmetics', 10: 'Automotive', 11: 'Childcare Equipment', 12: 'Injuries', 13: 'Chemical', 14: 'Fire', 15: 'Automotive', 16: 'Cosmetics', 17: 'other', 18: 'Chemical', 19: 'Injuries', 20: 'Cosmetics', 21: 'Clothing & Fashion', 22: 'Jewellery', 23: 'Chemical', 24: 'Injuries', 25: 'Fire', 26: 'Cosmetics', 27: 'Clothing & Fashion', 28: 'Automotive', 29: 'Injuries', 30: 'Fire', 31: 'Environment', 32: 'Automotive', 33: 'Chemicals', 34: 'Electrical Appliances', 35: 'Chemical', 36: 'Injuries', 37: 'Breathing Obstruction', 38: 'Cosmetics', 39: 'other', 40: 'Clothing & Fashion', 41: 'Chemical', 42: 'Injuries', 43: 'Breathing Obstruction', 44: 'Cosmetics', 45: 'Automotive', 46: 'Chemicals', 47: 'Injuries', 48: 'Environment', 49: 'Fire', 50: 'Automotive', 51: 'Toys', 52: 'Chemicals', 53: 'Microbiological', 54: 'Electric Shock', 55: 'Injuries', 56: 'other', 57: 'Electrical Appliances', 58: 'Automotive', 59: 'Injuries', 60: 'Chemical', 61: 'Breathing Obstruction', 62: 'Cosmetics', 63: 'Clothing & Fashion', 64: 'other', 65: 'Injuries', 66: 'Chemical', 67: 'Fire', 68: 'Automotive', 69: 'Cosmetics', 70: 'Chemicals', 71: 'Injuries', 72: 'Chemical', 73: 'Fire', 74: 'Automotive', 75: 'Cosmetics', 76: 'Chemicals', 77: 'Chemical', 78: 'Injuries', 79: 'Breathing Obstruction', 80: 'Cosmetics', 81: 'Toys', 82: 'Electrical Appliances', 83: 'Chemical', 84: 'Injuries', 85: 'Breathing Obstruction', 86: 'Cosmetics', 87: 'Automotive', 88: 'Toys'}, 'counts': {0: 249, 1: 118, 2: 116, 3: 211, 4: 176, 5: 66, 6: 98, 7: 37, 8: 15, 9: 99, 10: 59, 11: 2, 12: 128, 13: 35, 14: 26, 15: 143, 16: 27, 17: 12, 18: 21, 19: 1, 20: 15, 21: 4, 22: 1, 23: 375, 24: 95, 25: 9, 26: 353, 27: 78, 28: 32, 29: 28, 30: 8, 31: 5, 32: 41, 33: 1, 34: 1, 35: 90, 36: 17, 37: 4, 38: 85, 39: 8, 40: 6, 41: 72, 42: 10, 43: 3, 44: 64, 45: 8, 46: 7, 47: 6, 48: 2, 49: 2, 50: 9, 51: 1, 52: 1, 53: 1, 54: 1, 55: 1, 56: 1, 57: 1, 58: 1, 59: 32, 60: 27, 61: 5, 62: 24, 63: 21, 64: 9, 65: 24, 66: 20, 67: 7, 68: 32, 69: 16, 70: 4, 71: 17, 72: 15, 73: 8, 74: 25, 75: 11, 76: 5, 77: 543, 78: 118, 79: 110, 80: 205, 81: 192, 82: 138, 83: 176, 84: 57, 85: 19, 86: 138, 87: 35, 88: 24}, 'percentage': {0: 32.80632411067194, 1: 15.5467720685112, 2: 15.2832674571805, 3: 27.79973649538867, 4: 23.18840579710145, 5: 8.695652173913043, 6: 59.756097560975604, 7: 22.5609756097561, 8: 9.146341463414634, 9: 60.36585365853659, 10: 35.97560975609756, 11: 1.2195121951219512, 12: 62.4390243902439, 13: 17.073170731707318, 14: 12.682926829268293, 15: 69.7560975609756, 16: 13.170731707317074, 17: 5.853658536585367, 18: 95.45454545454545, 19: 4.545454545454546, 20: 68.18181818181817, 21: 18.181818181818183, 22: 4.545454545454546, 23: 75.75757575757575, 24: 19.19191919191919, 25: 1.8181818181818181, 26: 71.31313131313132, 27: 15.757575757575756, 28: 6.4646464646464645, 29: 65.11627906976744, 30: 18.6046511627907, 31: 11.627906976744185, 32: 95.34883720930233, 33: 2.3255813953488373, 34: 2.3255813953488373, 35: 75.63025210084034, 36: 14.285714285714285, 37: 3.361344537815126, 38: 71.42857142857143, 39: 6.722689075630252, 40: 5.042016806722689, 41: 79.12087912087912, 42: 10.989010989010989, 43: 3.296703296703297, 44: 70.32967032967034, 45: 8.791208791208792, 46: 7.6923076923076925, 47: 50.0, 48: 16.666666666666664, 49: 16.666666666666664, 50: 75.0, 51: 8.333333333333332, 52: 8.333333333333332, 53: 33.33333333333333, 54: 33.33333333333333, 55: 33.33333333333333, 56: 33.33333333333333, 57: 33.33333333333333, 58: 33.33333333333333, 59: 45.714285714285715, 60: 38.57142857142858, 61: 7.142857142857142, 62: 34.285714285714285, 63: 30.0, 64: 12.857142857142856, 65: 42.857142857142854, 66: 35.714285714285715, 67: 12.5, 68: 57.14285714285714, 69: 28.57142857142857, 70: 7.142857142857142, 71: 40.476190476190474, 72: 35.714285714285715, 73: 19.047619047619047, 74: 59.523809523809526, 75: 26.190476190476193, 76: 11.904761904761903, 77: 55.29531568228106, 78: 12.016293279022404, 79: 11.201629327902241, 80: 20.875763747454176, 81: 19.551934826883908, 82: 14.052953156822811, 83: 61.53846153846154, 84: 19.93006993006993, 85: 6.643356643356643, 86: 48.25174825174825, 87: 12.237762237762238, 88: 8.391608391608392}, 'country': {0: 'China', 1: 'China', 2: 'China', 3: 'China', 4: 'China', 5: 'China', 6: 'France', 7: 'France', 8: 'France', 9: 'France', 10: 'France', 11: 'France', 12: 'Germany', 13: 'Germany', 14: 'Germany', 15: 'Germany', 16: 'Germany', 17: 'Germany', 18: 'India', 19: 'India', 20: 'India', 21: 'India', 22: 'India', 23: 'Italy', 24: 'Italy', 25: 'Italy', 26: 'Italy', 27: 'Italy', 28: 'Italy', 29: 'Japan', 30: 'Japan', 31: 'Japan', 32: 'Japan', 33: 'Japan', 34: 'Japan', 35: 'Poland', 36: 'Poland', 37: 'Poland', 38: 'Poland', 39: 'Poland', 40: 'Poland', 41: 'Spain', 42: 'Spain', 43: 'Spain', 44: 'Spain', 45: 'Spain', 46: 'Spain', 47: 'Sweden', 48: 'Sweden', 49: 'Sweden', 50: 'Sweden', 51: 'Sweden', 52: 'Sweden', 53: 'Taiwan', 54: 'Taiwan', 55: 'Taiwan', 56: 'Taiwan', 57: 'Taiwan', 58: 'Taiwan', 59: 'Türkiye', 60: 'Türkiye', 61: 'Türkiye', 62: 'Türkiye', 63: 'Türkiye', 64: 'Türkiye', 65: 'UK', 66: 'UK', 67: 'UK', 68: 'UK', 69: 'UK', 70: 'UK', 71: 'USA', 72: 'USA', 73: 'USA', 74: 'USA', 75: 'USA', 76: 'USA', 77: 'Unknown', 78: 'Unknown', 79: 'Unknown', 80: 'Unknown', 81: 'Unknown', 82: 'Unknown', 83: 'other', 84: 'other', 85: 'other', 86: 'other', 87: 'other', 88: 'other'}, 'type': {0: 'risk', 1: 'risk', 2: 'risk', 3: 'category', 4: 'category', 5: 'category', 6: 'risk', 7: 'risk', 8: 'risk', 9: 'category', 10: 'category', 11: 'category', 12: 'risk', 13: 'risk', 14: 'risk', 15: 'category', 16: 'category', 17: 'category', 18: 'risk', 19: 'risk', 20: 'category', 21: 'category', 22: 'category', 23: 'risk', 24: 'risk', 25: 'risk', 26: 'category', 27: 'category', 28: 'category', 29: 'risk', 30: 'risk', 31: 'risk', 32: 'category', 33: 'category', 34: 'category', 35: 'risk', 36: 'risk', 37: 'risk', 38: 'category', 39: 'category', 40: 'category', 41: 'risk', 42: 'risk', 43: 'risk', 44: 'category', 45: 'category', 46: 'category', 47: 'risk', 48: 'risk', 49: 'risk', 50: 'category', 51: 'category', 52: 'category', 53: 'risk', 54: 'risk', 55: 'risk', 56: 'category', 57: 'category', 58: 'category', 59: 'risk', 60: 'risk', 61: 'risk', 62: 'category', 63: 'category', 64: 'category', 65: 'risk', 66: 'risk', 67: 'risk', 68: 'category', 69: 'category', 70: 'category', 71: 'risk', 72: 'risk', 73: 'risk', 74: 'category', 75: 'category', 76: 'category', 77: 'risk', 78: 'risk', 79: 'risk', 80: 'category', 81: 'category', 82: 'category', 83: 'risk', 84: 'risk', 85: 'risk', 86: 'category', 87: 'category', 88: 'category'}}
                 )

# %%
df
df['image'] = df['column'].map(img_dict)
df[df['country'] == 'Taiwan']
# Out:
#                    column  counts  percentage country      type  \
# 53        Microbiological       1   33.333333  Taiwan      risk
# 54         Electric Shock       1   33.333333  Taiwan      risk
# 55               Injuries       1   33.333333  Taiwan      risk
# 56                  other       1   33.333333  Taiwan  category
# 57  Electrical Appliances       1   33.333333  Taiwan  category
# 58             Automotive       1   33.333333  Taiwan  category
#
#                  image
# 53    microbiology.png
# 54           flash.png
# 55         patient.png
# 56           other.png
# 57  home-appliance.png
# 58             car.png

# %%
clist = df['country'].unique()
for name in clist:
    top3s(name, df)
# Out:
# no third value

# %%
top3s('Taiwan', df)

# %%
def top3s(country, frame):
    df = frame
    df_result = df[df['country']==country]

    img_dict={
    "Automotive":"car.png",
    "Breathing Obstruction":"breathing.png",
    "Chemical":"laboratory.png",
    "Chemicals":"laboratory.png",
    "Childcare Equipment":"childcare.png",
    "Clothing & Fashion":"fashion.png",
    "Cosmetics":"skincare.png",
    "Electric Shock":"flash.png",
    "Electrical Appliances":"home-appliance.png",
    "Environment":"environmental.png",
    "Fire":"fire.png",
    "Injuries":"patient.png",
    "Jewellery":"diamond-ring.png",
    "Microbiological":"microbiology.png",
    "Toys":"toys.png",
    "other": "other.png",
         }


    df_risk = df_result[df_result['type'] == 'risk'].copy()
    df_risk['image'] = df_risk['column'].map(img_dict)
    df_risk = df_risk.replace(' ', '\n', regex=True)
    df_risk['percentage'] = df_risk['percentage'].round(0).astype(int).astype(str) +' %'
    

    df_cat = df_result[df_result['type'] == 'category'].copy()
    df_cat['image'] = df_cat['column'].map(img_dict)
    
    df_cat = df_cat.replace(' ', '\n', regex=True)
    df_cat['percentage'] = df_cat['percentage'].round(0).astype(int).astype(str) + " %"
    

    country = df_cat['country'].iloc[0]
    
    


    import matplotlib.pyplot as plt
    import seaborn as sns
    from matplotlib.offsetbox import OffsetImage, AnnotationBbox
    import matplotlib.image as mpimg
    
    sns.set_theme(style="darkgrid")
    plt.style.use('fivethirtyeight')
    fig, ax = plt.subplots(figsize=(12, 4))
    
    color1 = '#4a94c9'
    color2 = '#ec8700'
    color3 = '#dbeaf4'
    color4 = '#fbe7cc'
    bgcolor = '#aecfe7'
    
    impath= 'img/icons/' # Jupyter
    # impath= 'img/icons'  #vscode
    
    fig.patch.set_facecolor(bgcolor)
    ax.set_facecolor('none')
    
    #plt.suptitle("2023", fontsize=16, ha='center', color="black")  # Adjust y position as needed
    
    #ax.text(0.01, 0.7, df_cat['country'].iloc[0], va = 'top',ha='center', fontsize=12, color='grey', bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})


    
    # Adding Section Titles
    
    ax.text(0.3, 0.9, 'THE THREE MOST COMMON ', ha='center', fontsize=18, color='white')
    ax.text(0.3, 0.8, 'PRODUCT CATEGORIES NOTIFIED', ha='center',fontsize=18, color='white')
    # Draw section HEADER rectangle
    p_box = plt.Rectangle((0.08, 0.76), 0.44, 0.23, color=color1, fill=color1, zorder = -1)
    # Draw section CONTENT rectangle
    p_lightbox = plt.Rectangle((0.08, 0.02), 0.44, 0.768, color=color3, fill=color1, zorder = -1)
    
    
    
    df = df_cat
    
    image_path = impath + df['image'].iloc[0]  # Update this to your image's path
    cat_image0 = mpimg.imread(image_path)
    cat_offset_image0 = OffsetImage(cat_image0, zoom=0.09)
    cat_image_box0 = AnnotationBbox(cat_offset_image0, (0.135, 0.45), frameon=False)
    
    image_path = impath + df['image'].iloc[1]  # Update this to your image's path
    cat_image1 = mpimg.imread(image_path)
    cat_offset_image1 = OffsetImage(cat_image1, zoom=0.09)
    cat_image_box1 = AnnotationBbox(cat_offset_image1, (0.32, 0.45), frameon=False)
    
    try:
        image_path = impath + df['image'].iloc[2]  # Update this to your image's path
        cat_image2 = mpimg.imread(image_path)
        cat_offset_image2 = OffsetImage(cat_image2, zoom=0.09)
        cat_image_box2 = AnnotationBbox(cat_offset_image2, (0.475, 0.45), frameon=False)
        ax.text(0.48, 0.7, df['percentage'].iloc[2], va = 'top', ha='center', fontsize=14, color=color1, fontweight='bold')
        #ax.text(0.48, 0.5, 'ICON3', ha='center', fontsize=14, color=color1)
        ax.text(0.48, 0.25, df['column'].iloc[2], va = 'top', ha='center', fontsize=14, color=color1, fontweight='bold')
        ax.add_artist(cat_image_box2)
    except:
        print("No Third Value")
    
    ax.text(0.135, 0.7, df['percentage'].iloc[0], va = 'top', ha='center', fontsize=14, color=color1, fontweight='bold')
    #ax.text(0.175, 0.5, 'ICON1', ha='center', fontsize=14, color=color1)
    ax.text(0.135, 0.25, df['column'].iloc[0], va = 'top', ha='center', fontsize=14, color=color1, fontweight='bold')
    
    
    ax.text(0.32, 0.7, df['percentage'].iloc[1], va = 'top', ha='center', fontsize=14, color=color1, fontweight='bold')
    #ax.text(0.32, 0.5, 'ICON2', ha='center', fontsize=14, color=color1)
    ax.text(0.32, 0.25, df['column'].iloc[1], va = 'top', ha='center', fontsize=14, color=color1, fontweight='bold')
    
    plt.annotate( df_cat['country'].iloc[0], xy=(0.01, 0.7),
            fontsize=10, ha='center', va='center', color='#404040')
    
    #####################################
    
    # Adding Section Titles
    
    ax.text(0.79, 0.9, 'THE THREE MOST COMMON ', ha='center', fontsize=18, color='white')
    ax.text(0.79, 0.8, 'RISKS NOTIFIED', ha='center',fontsize=18, color='white')
    
    # Draw section HEADER rectangle
    r_box = plt.Rectangle((0.58, 0.76), 0.44, 0.23, color=color2, fill=color2, zorder = -1)
    # Draw section CONTENT rectangle
    r_lightbox = plt.Rectangle((0.58, 0.02), 0.44, 0.768, color=color4, fill=color1, zorder = -1)
    
    
    df = df_risk
    
    image_path = impath + df['image'].iloc[0]  # Update this to your image's path
    
    risk_image0 = mpimg.imread(image_path)
    risk_offset_image0 = OffsetImage(risk_image0, zoom=0.09)
    risk_image_box0 = AnnotationBbox(risk_offset_image0, (0.64, 0.45), frameon=False)
    
    image_path = impath + df['image'].iloc[1]  # Update this to your image's path
    risk_image1 = mpimg.imread(image_path)
    risk_offset_image1 = OffsetImage(risk_image1, zoom=0.09)
    risk_image_box1 = AnnotationBbox(risk_offset_image1, (0.785, 0.45), frameon=False)
    
    try:
        image_path = impath + df['image'].iloc[2]  # Update this to your image's path
        risk_image2 = mpimg.imread(image_path)
        risk_offset_image2 = OffsetImage(risk_image2, zoom=0.09)
        risk_image_box2 = AnnotationBbox(risk_offset_image2, (0.93, 0.45), frameon=False)
        ax.text(0.935, 0.7, df['percentage'].iloc[2], va = 'top', ha='center', fontsize=14, color=color2, fontweight='bold')
        #ax.text(0.935, 0.5, 'ICON2', ha='center', fontsize=14, color=color2)
        ax.text(0.935, 0.25, df['column'].iloc[2], va = 'top', ha='center', fontsize=14, color=color2, fontweight='bold')
        ax.add_artist(risk_image_box2)
    except:
        print('no third value')
    
    ax.text(0.645, 0.7, df['percentage'].iloc[0], va = 'top', ha='center', fontsize=14, color=color2, fontweight='bold')
    #ax.text(0.645, 0.5, 'ICON1', ha='center', fontsize=14, color=color2)
    ax.text(0.645, 0.25, df['column'].iloc[0], va = 'top', ha='center', fontsize=14, color=color2, fontweight='bold')
    
    ax.text(0.79, 0.7, df['percentage'].iloc[1], va = 'top', ha='center', fontsize=14, color=color2, fontweight='bold')
    #ax.text(0.79, 0.5, 'ICON2', ha='center', fontsize=14, color=color2)
    ax.text(0.79, 0.25, df['column'].iloc[1], va = 'top', ha='center', fontsize=14, color=color2, fontweight='bold')
    
    
    # Drawing boxes
    
    ax.add_artist(p_box)
    ax.add_artist(p_lightbox)
    ax.add_artist(r_box)
    ax.add_artist(r_lightbox)
    
    ax.add_artist(cat_image_box0)
    ax.add_artist(cat_image_box1)
   
    ax.add_artist(risk_image_box0)
    ax.add_artist(risk_image_box1)
    
    
    ax.grid(False)
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    
    ax.set_xticks([])
    ax.set_yticks([])
    
    
    # Setting limits and showing plot
    # ax.set_xlim(0, 1)

    # ax.set_ylim(0, 1)
    #plt.tight_layout()
